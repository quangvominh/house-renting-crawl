# %%
# Using Selenium to crawl data, as we using Edge, we will use webdriver of Edge

from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By
import time
class SeleniumCrawler:
    def __init__(self) -> None:
        self.options = Options()

        # window size of selenium
        self.options.add_argument("--window-size=128,70")
        self.options.add_argument("--headless")
        # Disable GPU
        self.options.add_argument("--disable-gpu")
        # Using header to avoid being blocked by web
        self.options.add_argument(
            "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36")
        self.driver = webdriver.Edge(options=self.options)

    def crawl(self, url: str, selector: str, script: str = None, sleep: int = 1):
        # Running URL
        self.driver.get(url)
        time.sleep(sleep)
        if script != None:
            self.driver.execute_script(script)
        # Grabbing element with css selector which match
        els = self.driver.find_elements(By.CSS_SELECTOR, selector)
        return els

    # Similar to crawling above, with the task of crawling multiple selectors
    def crawl_muti_selectors(self, url: str, selectors: list[str], script: str = None, sleep: int = 1):
        self.driver.get(url)
        time.sleep(sleep)
        if script != None:
            self.driver.execute_script(script)
        els = []
        for selector in selectors:
            els.append(self.driver.find_elements(By.CSS_SELECTOR, selector))
        return els

    # Similar to the crawl above, the task can be to crawl multiple selectors, but all elements will be joined together into a list.
    def crawl_squence_selectors(self, url: str, selectors: list[str], script: str = None, sleep: int = 1):
        self.driver.get(url)
        time.sleep(sleep)
        if script != None:
            self.driver.execute_script(script)
        els = []
        for selector in selectors:
            els += self.driver.find_elements(By.CSS_SELECTOR, selector)
        return els
    # Turn off driver
    def quit(self):
        self.driver.quit()

# %%
## link https://www.nhatot.com/mua-ban-nha-dat-tp-ho-chi-minh?page=2

import pandas as pd
from multiprocessing import Queue
from selenium.webdriver.common.by import By
from threading import Thread

# Additional information about elements to crawl
class CrawledElementInfo:
    #selector of element with neccessary information
    container_selector = "div.AdParam_adParamContainerVeh__Vz4Zt > div"
    #format for selector of label contains the necessary information.
    selector_format_value = "div.AdParam_adParamContainerVeh__Vz4Zt > div:nth-child({index}) > div > div.media-body.media-middle > span > span.AdParam_adParamValue__IfaYa"
    #format for the value selector contains the necessary information.
    selector_format_label = "div.AdParam_adParamContainerVeh__Vz4Zt > div:nth-child({index}) > div > div.media-body.media-middle > span > span:nth-child(1)"
    #selector of address
    address = "span.fz13"
    #selector of price
    price = "span.AdDecriptionVeh_price__u_N83 > span:nth-child(1)"
    #lable of area
    area_label = "Diện tích"
    #label of bedroom
    bedroom_num_label = "Số phòng ngủ"
    #label of floor
    floor_num_label = "Tổng số tầng"
    #label of floor
    legal_document_label = "Giấy tờ pháp lý"
    #label of building_type
    building_type_label = "Loại hình nhà ở"

# Function to crawl product's url in one home page.
def crawl_url_multithread(input: Queue,output: Queue, page_url: str):
    # When there are still other pages to crawl
    while not input.empty():
        # Retreive page number
        page = input.get()
        crawler = SeleniumCrawler()
        # crawl
        containers = crawler.crawl(page_url.format(page=page), "a.AdItem_adItem__gDDQT")
        urls = []
        # Add url into output
        for container in containers:
            building_detail_url = container.get_attribute("href")
            output.put(building_detail_url)
            urls.append(building_detail_url)
        crawler.quit()
        print(f"Get {len(urls)} urls in page {page}...")

# Function to crawl product's information in a product
def crawl_with_process(input: Queue, output: Queue):
    while not input.empty():
        # Data column
        data = {
            "Giá nhà": [None],
            "Địa chỉ": [None],
            "Diện tích": [None],
            "Số phòng ngủ": [None],
            "Tổng số tầng": [None],
            "Loại hình nhà ở": [None],
            "Giấy tờ pháp lý": [None],
            "url": [None],
        }
        # Find url from input data
        url = input.get()
        data["url"] = url
        crawler = SeleniumCrawler()
        crawler.driver.get(url)
        # Find element of address
        address = crawler.driver.find_elements(
            By.CSS_SELECTOR, CrawledElementInfo.address
        )
        # Find element of "không tìm thấy sản phẩm"
        not_found = crawler.driver.find_elements(By.CSS_SELECTOR, "div.NotFound_content__KtIbC")
        # If there are none of above elements, refresh the page
        while (len(address) == 0) and (len(not_found) == 0):
            print(f"Try again {url}...")
            crawler.driver.refresh()
            address = crawler.driver.find_elements(
                By.CSS_SELECTOR, CrawledElementInfo.address
            )
            not_found = crawler.driver.find_elements(By.CSS_SELECTOR, "div.NotFound_content__KtIbC")
        # If there are no information about the products, skip the product
        if len(not_found) != 0:
            print(f"Not found {url}...")
            crawler.quit()
            continue
        # If there are informations, lưu lại thông tin address
        if len(address) != 0:
            data["Địa chỉ"][0] = address[0].text.split("\n")[0]
        # Crawl price and save price
        price = crawler.driver.find_elements(
            By.CSS_SELECTOR, CrawledElementInfo.price
        )
        if len(price) != 0:
            data["Giá nhà"][0] = price[0].text.split("-")[0].strip()
        # Count the structured data
        info_num = len(
            crawler.driver.find_elements(
                By.CSS_SELECTOR, CrawledElementInfo.container_selector
            )
        )
        # With every strutured data
        for i in range(info_num):
            # Crawl label
            label_el = crawler.driver.find_element(
                By.CSS_SELECTOR,
                CrawledElementInfo.selector_format_label.format(index=i + 1),
            )
            # Crawl value
            value = crawler.driver.find_element(
                By.CSS_SELECTOR,
                CrawledElementInfo.selector_format_value.format(index=i + 1),
            )
            # Preprocessing the data
            label = label_el.text.split(":")[0]
            # If the label belongs to the information that needs to be retrieved, then save the value
            if label in [
                CrawledElementInfo.area_label.strip(),
                CrawledElementInfo.bedroom_num_label.strip(),
                CrawledElementInfo.floor_num_label.strip(),
                CrawledElementInfo.legal_document_label.strip(),
                CrawledElementInfo.building_type_label.strip(),
            ]:
                data[label][0] = value.text

        crawler.quit()
        # Save into output
        output.put(data)
        df = pd.DataFrame(data)
        # insert datas into sheet named file data.csv
        df.to_csv("data.csv", mode="a", encoding="utf-8-sig", header=False, index=False)
        print(f"Crawled: {output.qsize()}.{data}")

# Main processing function
def get_data(url: str, from_page: int, to_page: int = 100):
    # List datas
    data = {
        "Giá nhà": [],
        "Địa chỉ": [],
        "Diện tích": [],
        "Số phòng ngủ": [],
        "Tổng số tầng": [],
        "Loại hình nhà ở": [],
        "Giấy tờ pháp lý": [],
        "url": [],
    }
    # Create sheet data.csv
    pd.DataFrame(data).to_csv("data.csv", encoding="utf-8-sig", index=False)
    input = Queue()
    sub_input = Queue()
    output = Queue()
    # Load pages url needs to be crawled into sub_input
    for i in range(to_page - from_page + 1):
        sub_input.put(i+1)
    crawl_url_threads = []
    # Crawl url using 4 thread to speedup crawl. Thread is different from process, 1 process can have many threads.
    for _ in range(4):
        crawl_url_thread = Thread(target=crawl_url_multithread, args=(sub_input,input, url))
        crawl_url_threads.append(crawl_url_thread)
    # Start running threads
    for crawl_url_thread in crawl_url_threads:
        crawl_url_thread.start()
    # Waiting for threads to finish running
    for crawl_url_thread in crawl_url_threads:
        crawl_url_thread.join()
    print("Detect {} buidling".format(input.qsize()))
    processes = []

    ## Run 12 threads
    for _ in range(12):
        process = Thread(target=crawl_with_process, args=(input, output))
        processes.append(process)
    # Start running threads
    for process in processes:
        process.start()
    # Waiting for threads to finish running
    for process in processes:
        process.join()
    # Load datas into an array from output and return to that array
    while not output.empty():
        crawled_data = output.get()
        for key in crawled_data.keys():
            data[key].append(crawled_data[key])
    output.close()
    input.close()
    return data

# %%
if __name__ == "__main__":
    url = "https://www.nhatot.com/mua-ban-nha-dat-tp-ho-chi-minh?page={page}"
    datas = get_data(url, 1, 200)
# Out:
# Get 20 urls in page 3...
# Get 22 urls in page 2...
# Get 20 urls in page 4...
# Get 25 urls in page 1...
# Get 20 urls in page 5...
# Get 20 urls in page 6...
# Get 20 urls in page 7...
# Get 20 urls in page 8...
# Get 20 urls in page 9...
# Get 20 urls in page 10...
# Get 20 urls in page 11...
# Get 20 urls in page 12...
# Get 20 urls in page 13...
# Get 20 urls in page 14...
# Get 20 urls in page 16...
# Get 20 urls in page 15...
# Get 20 urls in page 17...
# Get 20 urls in page 19...
# Get 20 urls in page 18...
# Get 20 urls in page 20...
# Get 20 urls in page 21...
# Get 20 urls in page 22...
# Get 20 urls in page 23...
# Get 20 urls in page 24...
# Get 20 urls in page 25...
# Get 20 urls in page 26...
# Get 20 urls in page 27...
# Get 20 urls in page 28...
# Get 20 urls in page 29...
# Get 20 urls in page 30...
# Get 20 urls in page 31...
# Get 20 urls in page 32...
# Get 20 urls in page 33...
# Get 20 urls in page 34...
# Get 20 urls in page 35...
# Get 20 urls in page 36...
# Get 20 urls in page 37...
# Get 20 urls in page 38...
# Get 20 urls in page 39...
# Get 20 urls in page 40...
# Get 20 urls in page 41...
# Get 20 urls in page 42...
# Get 20 urls in page 43...
# Get 20 urls in page 44...
# Get 20 urls in page 45...
# Get 20 urls in page 46...
# Get 20 urls in page 47...
# Get 20 urls in page 48...
# Get 20 urls in page 49...
# Get 20 urls in page 50...
# Get 20 urls in page 51...
# Get 20 urls in page 52...
# Get 20 urls in page 53...
# Get 20 urls in page 54...
# Get 20 urls in page 55...
# Get 20 urls in page 56...
# Get 20 urls in page 57...
# Get 20 urls in page 58...
# Get 20 urls in page 59...
# Get 20 urls in page 60...
# Get 20 urls in page 61...
# Get 20 urls in page 62...
# Get 20 urls in page 63...
# Get 20 urls in page 64...
# Get 20 urls in page 65...
# Get 20 urls in page 66...
# Get 20 urls in page 67...
# Get 20 urls in page 68...
# Get 20 urls in page 69...
# Get 20 urls in page 70...
# Get 20 urls in page 71...
# Get 20 urls in page 72...
# Get 20 urls in page 73...
# Get 20 urls in page 74...
# Get 20 urls in page 75...
# Get 20 urls in page 76...
# Get 20 urls in page 77...
# Get 20 urls in page 78...
# Get 20 urls in page 79...
# Get 20 urls in page 80...
# Get 20 urls in page 81...
# Get 20 urls in page 82...
# Get 20 urls in page 83...
# Get 20 urls in page 84...
# Get 20 urls in page 85...
# Get 20 urls in page 86...
# Get 20 urls in page 87...
# Get 20 urls in page 88...
# Get 20 urls in page 89...
# Get 20 urls in page 90...
# Get 20 urls in page 91...
# Get 20 urls in page 93...
# Get 20 urls in page 92...
# Get 20 urls in page 94...
# Get 20 urls in page 95...
# Get 20 urls in page 96...
# Get 20 urls in page 97...
# Get 20 urls in page 98...
# Get 20 urls in page 99...
# Get 20 urls in page 100...
# Get 20 urls in page 101...
# Get 20 urls in page 102...
# Get 20 urls in page 103...
# Get 20 urls in page 104...
# Get 20 urls in page 105...
# Get 20 urls in page 106...
# Get 20 urls in page 107...
# Get 20 urls in page 108...
# Get 20 urls in page 109...
# Get 20 urls in page 110...
# Get 20 urls in page 111...
# Get 20 urls in page 112...
# Get 20 urls in page 113...
# Get 20 urls in page 114...
# Get 20 urls in page 115...
# Get 20 urls in page 116...
# Get 20 urls in page 117...
# Get 20 urls in page 118...
# Get 20 urls in page 119...
# Get 20 urls in page 120...
# Get 20 urls in page 121...
# Get 20 urls in page 122...
# Get 20 urls in page 123...
# Get 20 urls in page 124...
# Get 20 urls in page 125...
# Get 20 urls in page 126...
# Get 20 urls in page 127...
# Get 20 urls in page 128...
# Get 20 urls in page 129...
# Get 20 urls in page 130...
# Get 20 urls in page 131...
# Get 20 urls in page 132...
# Get 20 urls in page 133...
# Get 20 urls in page 134...
# Get 20 urls in page 135...
# Get 20 urls in page 136...
# Get 20 urls in page 137...
# Get 20 urls in page 138...
# Get 20 urls in page 139...
# Get 20 urls in page 140...
# Get 20 urls in page 141...
# Get 20 urls in page 142...
# Get 20 urls in page 143...
# Get 20 urls in page 144...
# Get 20 urls in page 145...
# Get 20 urls in page 146...
# Get 20 urls in page 147...
# Get 20 urls in page 148...
# Get 20 urls in page 149...
# Get 20 urls in page 150...
# Get 20 urls in page 151...
# Get 20 urls in page 152...
# Get 20 urls in page 153...
# Get 20 urls in page 154...
# Get 20 urls in page 155...
# Get 20 urls in page 156...
# Get 20 urls in page 157...
# Get 20 urls in page 158...
# Get 20 urls in page 159...
# Get 20 urls in page 160...
# Get 20 urls in page 161...
# Get 20 urls in page 162...
# Get 20 urls in page 163...
# Get 20 urls in page 164...
# Get 20 urls in page 165...
# Get 20 urls in page 166...
# Get 20 urls in page 167...
# Get 20 urls in page 168...
# Get 20 urls in page 169...
# Get 20 urls in page 170...
# Get 20 urls in page 171...
# Get 20 urls in page 172...
# Get 20 urls in page 173...
# Get 20 urls in page 174...
# Get 20 urls in page 175...
# Get 20 urls in page 176...
# Get 20 urls in page 177...
# Get 20 urls in page 178...
# Get 20 urls in page 179...
# Get 20 urls in page 180...
# Get 20 urls in page 181...
# Get 20 urls in page 182...
# Get 20 urls in page 183...
# Get 20 urls in page 184...
# Get 20 urls in page 185...
# Get 20 urls in page 186...
# Get 20 urls in page 187...
# Get 20 urls in page 188...
# Get 20 urls in page 189...
# Get 20 urls in page 190...
# Get 20 urls in page 191...
# Get 20 urls in page 192...
# Get 20 urls in page 193...
# Get 20 urls in page 194...
# Get 20 urls in page 195...
# Get 20 urls in page 196...
# Get 20 urls in page 197...
# Get 20 urls in page 198...
# Get 20 urls in page 199...
# Get 20 urls in page 200...
# Detect 4007 buidling
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/109533309.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/106695303.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-phu-nhuan-tp-ho-chi-minh/110819605.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110750901.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110716050.htm#px=SR-special_display_ad-[PO-2][PL-default]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830551.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830580.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830694.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110429010.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830666.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830670.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110647133.htm#px=SR-special_display_ad-[PO-6][PL-default]...
# Crawled: 1.{'Giá nhà': ['7,49 tỷ'], 'Địa chỉ': ['17 Đường Liên Khu 8-9 , Phường Bình Hưng Hoà A , Bình Tân , Thành Phố Hồ Chí Minh, Phường Bình Hưng Hoà A, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['80 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': ['1'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/109533309.htm'}
# Crawled: 2.{'Giá nhà': ['5,4 tỷ'], 'Địa chỉ': ['Đường Tô Hiệu, Phường Hiệp Tân, Quận Tân Phú, Tp Hồ Chí Minh'], 'Diện tích': ['75 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110429010.htm'}
# Crawled: 4.{'Giá nhà': ['315 triệu'], 'Địa chỉ': ['Đường An Hạ, Xã Phạm Văn Hai, Huyện Bình Chánh, Tp Hồ Chí Minh'], 'Diện tích': ['100 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['1'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/106695303.htm'}
# Crawled: 4.{'Giá nhà': ['11,5 tỷ'], 'Địa chỉ': ['Nguyễn Xiển, Phường Long Thạnh Mỹ (Quận 9 cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['84 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà phố liền kề'], 'Giấy tờ pháp lý': ['Đang chờ sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830666.htm'}
# Crawled: 5.{'Giá nhà': ['6,28 tỷ'], 'Địa chỉ': ['Hà Huy Giáp, Phường Thạnh Lộc, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['98 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110750901.htm'}
# Crawled: 6.{'Giá nhà': ['10,48 tỷ'], 'Địa chỉ': ['Đường Hiệp Bình, Phường Hiệp Bình Phước (Quận Thủ Đức cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['120 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110647133.htm#px=SR-special_display_ad-[PO-6][PL-default]'}
# Crawled: 7.{'Giá nhà': ['5,7 tỷ'], 'Địa chỉ': ['Nguyễn Ảnh Thủ, Phường Hiệp Thành, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['62 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà phố liền kề'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110716050.htm#px=SR-special_display_ad-[PO-2][PL-default]'}
# Crawled: 8.{'Giá nhà': ['4,6 tỷ'], 'Địa chỉ': ['Bùi Quang Là, Phường 12, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['48 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830694.htm'}
# Crawled: 9.{'Giá nhà': ['4,9 tỷ'], 'Địa chỉ': ['Nguyễn Hồng Đào, Phường 14, Quận Tân Bình, Tp Hồ Chí Minh'], 'Diện tích': ['40 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830580.htm'}
# Crawled: 10.{'Giá nhà': ['1,29 tỷ'], 'Địa chỉ': ['Nguyễn Văn Quá, Phường Đông Hưng Thuận, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['21 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830670.htm'}
# Crawled: 11.{'Giá nhà': ['4,1 tỷ'], 'Địa chỉ': ['Đường Số 6, Phường An Lạc, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['36 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830551.htm'}
# Crawled: 12.{'Giá nhà': ['7,69 tỷ'], 'Địa chỉ': ['Hẻm 39 Đường Huỳnh Văn Bánh, Phường 17, Quận Phú Nhuận, Tp Hồ Chí Minh'], 'Diện tích': ['68 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-phu-nhuan-tp-ho-chi-minh/110819605.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110821306.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110830525.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110830539.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830532.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830542.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/109838641.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/105539236.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-8-tp-ho-chi-minh/110830503.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110750649.htm#px=SR-stickyad-[PO-1][PL-top]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/104606063.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110751244.htm...
# Crawled: 13.{'Giá nhà': ['3,7 tỷ'], 'Địa chỉ': ['Nguyễn Văn Nghi, Phường 4, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['46 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110821306.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110565282.htm...
# Crawled: 14.{'Giá nhà': ['4,18 tỷ'], 'Địa chỉ': ['Đường Tân Kỳ Tân Quý, Phường Tân Quý, Quận Tân Phú, Tp Hồ Chí Minh'], 'Diện tích': ['48 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110830525.htm'}
# Crawled: 15.{'Giá nhà': ['5,95 tỷ'], 'Địa chỉ': ['Đường Bùi Đình Tuý, Phường 12, Quận Bình Thạnh, Tp Hồ Chí Minh'], 'Diện tích': ['54 m²'], 'Số phòng ngủ': ['9 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110830539.htm'}
# Crawled: 16.{'Giá nhà': ['5,7 tỷ'], 'Địa chỉ': ['Nguyen Duy Trinh, Phường Phú Hữu (Quận 9 cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['57 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110750649.htm#px=SR-stickyad-[PO-1][PL-top]'}
# Crawled: 17.{'Giá nhà': ['6,4 tỷ'], 'Địa chỉ': ['Phạm Văn Chiêu, Phường 16, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['70 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830542.htm'}
# Crawled: 18.{'Giá nhà': ['3,98 tỷ'], 'Địa chỉ': ['Tỉnh lộ 10, Phường Bình Trị Đông A, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['49.3 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830532.htm'}
# Crawled: 19.{'Giá nhà': ['4,2 tỷ'], 'Địa chỉ': ['Duong So 7 TM-TX, Xã Tân Xuân, Huyện Hóc Môn, Tp Hồ Chí Minh'], 'Diện tích': ['63 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/109838641.htm'}
# Crawled: 20.{'Giá nhà': ['670 triệu'], 'Địa chỉ': ['Đường Bộ Đội An Điền, Xã Vĩnh Lộc A, Huyện Bình Chánh, Tp Hồ Chí Minh'], 'Diện tích': ['20 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/104606063.htm'}
# Crawled: 21.{'Giá nhà': ['14,8 tỷ'], 'Địa chỉ': ['Hà Huy Giáp, Phường Thạnh Lộc, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['678 m²'], 'Số phòng ngủ': ['6 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110751244.htm'}
# Crawled: 22.{'Giá nhà': ['16,8 tỷ'], 'Địa chỉ': ['Thoại Ngọc Hầu, Phường Hiệp Tân, Quận Tân Phú, Tp Hồ Chí Minh'], 'Diện tích': ['155 m²'], 'Số phòng ngủ': ['6 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/105539236.htm'}
# Crawled: 23.{'Giá nhà': ['3 tỷ'], 'Địa chỉ': ['Phạm Thế Hiển, Phường 6, Quận 8, Tp Hồ Chí Minh'], 'Diện tích': ['30 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-8-tp-ho-chi-minh/110830503.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830878.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110240512.htm#px=SR-stickyad-[PO-2][PL-top]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830868.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830853.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830846.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-cu-chi-tp-ho-chi-minh/110630190.htm#px=SR-special_display_ad-[PO-9][PL-default]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830809.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830804.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/109135715.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-nha-be-tp-ho-chi-minh/109966486.htm#px=SR-special_display_ad-[PO-6][PL-default]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/110830778.htm#px=SR-special_display_ad-[PO-13][PL-default]...
# Crawled: 24.{'Giá nhà': ['10,5 tỷ'], 'Địa chỉ': ['Phùng Tá Chu, Phường An Lạc A, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['78 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110565282.htm'}
# Crawled: 25.{'Giá nhà': ['16,5 tỷ'], 'Địa chỉ': ['Đường Tăng Nhơn Phú, Phường Tăng Nhơn Phú B (Quận 9 cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['260 m²'], 'Số phòng ngủ': ['nhiều hơn 10 phòng'], 'Tổng số tầng': ['5'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830878.htm'}
# Crawled: 26.{'Giá nhà': ['6,2 tỷ'], 'Địa chỉ': ['Phan Huy Ích, Phường 14, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['54 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830868.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830775.htm...
# Crawled: 27.{'Giá nhà': ['3,549 tỷ'], 'Địa chỉ': ['Lê Văn Qưới, Phường Bình Hưng Hoà A, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['80 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830846.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/109772853.htm...
# Crawled: 28.{'Giá nhà': ['5,5 tỷ'], 'Địa chỉ': ['Nguyên Hồng, Phường 1, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['53 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830853.htm'}
# Crawled: 29.{'Giá nhà': ['1,75 tỷ'], 'Địa chỉ': ['Đường Phan Văn Trị, Phường 11, Quận Bình Thạnh, Tp Hồ Chí Minh'], 'Diện tích': ['18 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['1'], 'Loại hình nhà ở': [None], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110240512.htm#px=SR-stickyad-[PO-2][PL-top]'}
# Crawled: 30.{'Giá nhà': ['4,9 tỷ'], 'Địa chỉ': ['797, Xã An Phú, Huyện Củ Chi, Tp Hồ Chí Minh'], 'Diện tích': ['600 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà biệt thự'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-cu-chi-tp-ho-chi-minh/110630190.htm#px=SR-special_display_ad-[PO-9][PL-default]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110628787.htm...
# Crawled: 31.{'Giá nhà': ['4,29 tỷ'], 'Địa chỉ': ['Quốc lộ 1, Phường An Phú Đông, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['121 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830809.htm'}
# Crawled: 32.{'Giá nhà': ['7,5 tỷ'], 'Địa chỉ': ['Dương Quảng Hàm, Phường 5, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['47.56 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà phố liền kề'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/109135715.htm'}
# Crawled: 33.{'Giá nhà': ['3,2 tỷ'], 'Địa chỉ': ['Phạm Hữu Lầu, Xã Phước Kiển, Huyện Nhà Bè, Tp Hồ Chí Minh'], 'Diện tích': ['49.1 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-nha-be-tp-ho-chi-minh/109966486.htm#px=SR-special_display_ad-[PO-6][PL-default]'}
# Crawled: 34.{'Giá nhà': ['4,999 tỷ'], 'Địa chỉ': ['Nguyễn Thị Kiểu, Phường Hiệp Thành, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['50 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830804.htm'}
# Crawled: 35.{'Giá nhà': ['7 tỷ'], 'Địa chỉ': ['Trịnh Quang Nghị, Xã Phong Phú, Huyện Bình Chánh, Tp Hồ Chí Minh'], 'Diện tích': ['75 m²'], 'Số phòng ngủ': ['6 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà phố liền kề'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/110830778.htm#px=SR-special_display_ad-[PO-13][PL-default]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830730.htm#px=SR-special_display_ad-[PO-18][PL-default]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-3-tp-ho-chi-minh/109584022.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110830720.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-11-tp-ho-chi-minh/110091148.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830499.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110545400.htm#px=SR-special_display_ad-[PO-20][PL-default]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-3-tp-ho-chi-minh/106423173.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110755442.htm#px=SR-special_display_ad-[PO-5][PL-default]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830452.htm...
# Crawled: 36.{'Giá nhà': ['6,7 tỷ'], 'Địa chỉ': ['Hoàng Hoa Thám, Phường 5, Quận Bình Thạnh, Tp Hồ Chí Minh'], 'Diện tích': ['93 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/109772853.htm'}
# Crawled: 37.{'Giá nhà': ['5,39 tỷ'], 'Địa chỉ': ['Xô Viết Nghệ Tĩnh, Phường 17, Quận Bình Thạnh, Tp Hồ Chí Minh'], 'Diện tích': ['53 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110628787.htm'}
# Crawled: 38.{'Giá nhà': ['1 tỷ'], 'Địa chỉ': ['551/221/2/10, Lê Văn Khương, Phường Hiệp Thành, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['20 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830775.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110736080.htm...
# Crawled: 39.{'Giá nhà': ['7,7 tỷ'], 'Địa chỉ': ['Lô Tư, Phường Bình Hưng Hoà A, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['70 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830730.htm#px=SR-special_display_ad-[PO-18][PL-default]'}
# Crawled: 40.{'Giá nhà': ['48,99 tỷ'], 'Địa chỉ': ['Ðiện Biên Phủ, Phường 1, Quận 3, Tp Hồ Chí Minh'], 'Diện tích': ['112 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-3-tp-ho-chi-minh/109584022.htm'}
# Crawled: 41.{'Giá nhà': ['6,9 tỷ'], 'Địa chỉ': ['Lâm Văn Bền, Phường Tân Kiểng, Quận 7, Tp Hồ Chí Minh'], 'Diện tích': ['65 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110830720.htm'}
# Crawled: 42.{'Giá nhà': ['2 tỷ'], 'Địa chỉ': ['Lý Thường Kiệt, Phường 9, Quận Tân Bình, Tp Hồ Chí Minh'], 'Diện tích': ['22 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830499.htm'}
# Crawled: 43.{'Giá nhà': ['6,5 tỷ'], 'Địa chỉ': ['Hàn Hải Nguyên, Phường 3, Quận 11, Tp Hồ Chí Minh'], 'Diện tích': ['65 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-11-tp-ho-chi-minh/110091148.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/110684914.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-nha-be-tp-ho-chi-minh/110545672.htm#px=SR-special_display_ad-[PO-8][PL-default]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830420.htm...
# Crawled: 44.{'Giá nhà': ['11 tỷ'], 'Địa chỉ': ['Nguyễn Thiện Thuật, Phường 2, Quận 3, Tp Hồ Chí Minh'], 'Diện tích': ['44 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': ['5'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-3-tp-ho-chi-minh/106423173.htm'}
# Crawled: 45.{'Giá nhà': ['6,8 tỷ'], 'Địa chỉ': ['Đường Huỳnh Tấn Phát, Phường Phú Mỹ, Quận 7, Tp Hồ Chí Minh'], 'Diện tích': ['56 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110545400.htm#px=SR-special_display_ad-[PO-20][PL-default]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110830389.htm...
# Crawled: 46.{'Giá nhà': ['5,7 tỷ'], 'Địa chỉ': ['Đường Số 4, Phường Trường Thọ (Quận Thủ Đức cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['96 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830452.htm'}
# Crawled: 47.{'Giá nhà': ['6,7 tỷ'], 'Địa chỉ': ['Hẻm 190 Lý Thánh Tông, Phường Hiệp Tân, Quận Tân Phú, Tp Hồ Chí Minh'], 'Diện tích': ['60 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['5'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110755442.htm#px=SR-special_display_ad-[PO-5][PL-default]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830352.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830365.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/82269443.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110668892.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/109626283.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110830321.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/109998656.htm...
# Crawled: 48.{'Giá nhà': ['5,6 tỷ'], 'Địa chỉ': ['Thới An 21, Phường Thới An, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['57 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110736080.htm'}
# Crawled: 49.{'Giá nhà': ['1,65 tỷ'], 'Địa chỉ': ['Đường Đinh Đức Thiện, Xã Bình Chánh, Huyện Bình Chánh, Tp Hồ Chí Minh'], 'Diện tích': ['100 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['1'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/110684914.htm'}
# Crawled: 50.{'Giá nhà': ['5,6 tỷ'], 'Địa chỉ': ['Đường Đào Tông Nguyên, Xã Phú Xuân, Nhà Bè, Hồ Chí Minh, Xã Phú Xuân, Huyện Nhà Bè, Tp Hồ Chí Minh'], 'Diện tích': ['50 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-nha-be-tp-ho-chi-minh/110545672.htm#px=SR-special_display_ad-[PO-8][PL-default]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110694272.htm...
# Crawled: 51.{'Giá nhà': ['3,5 tỷ'], 'Địa chỉ': ['Lương Ngọc Quyến, Phường 5, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['50 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830420.htm'}
# Crawled: 52.{'Giá nhà': ['10 tỷ'], 'Địa chỉ': ['659 Âu Cơ, phường Tân Thành, quận Tân Phú, Tp. HCM., Phường Tân Thành, Quận Tân Phú, Tp Hồ Chí Minh'], 'Diện tích': ['384.26 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110830389.htm'}
# Crawled: 54.{'Giá nhà': ['2,04 tỷ'], 'Địa chỉ': ['Đường Tân Thới Hiệp 09, Phường Tân Thới Hiệp, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['19 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830352.htm'}
# Crawled: 54.{'Giá nhà': ['2,58 tỷ'], 'Địa chỉ': ['72/2/15 Thới An 10, Phường Thới An, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['30 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110830365.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830296.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/109631106.htm...
# Crawled: 55.{'Giá nhà': ['3,7 tỷ'], 'Địa chỉ': ['Đường 14, Phường Linh Chiểu (Quận Thủ Đức cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['43 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/82269443.htm'}
# Crawled: 56.{'Giá nhà': ['3,75 tỷ'], 'Địa chỉ': ['Vườn Lài, Phường Phú Thọ Hòa, Quận Tân Phú, Tp Hồ Chí Minh'], 'Diện tích': ['40 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110830321.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110766298.htm#px=SR-stickyad-[PO-1][PL-top]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110814433.htm#px=SR-stickyad-[PO-2][PL-top]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110687525.htm#px=SR-stickyad-[PO-4][PL-top]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110102493.htm#px=SR-stickyad-[PO-3][PL-top]...
# Crawled: 57.{'Giá nhà': ['1,35 tỷ'], 'Địa chỉ': ['Hiệp Bình Chánh, Phường Hiệp Bình Chánh (Quận Thủ Đức cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['25 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Giấy tờ khác'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110668892.htm'}
# Crawled: 58.{'Giá nhà': ['17,5 tỷ'], 'Địa chỉ': ['Cách Mạng Tháng Tám, Phường Hiệp Bình Phước (Quận Thủ Đức cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['102 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/109998656.htm'}
# Crawled: 59.{'Giá nhà': ['5,3 tỷ'], 'Địa chỉ': ['Ni Sư Huỳnh Liên, Phường 10, Quận Tân Bình, Tp Hồ Chí Minh'], 'Diện tích': ['60 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['5'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/109626283.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-8-tp-ho-chi-minh/110816618.htm#px=SR-stickyad-[PO-5][PL-top]...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-8-tp-ho-chi-minh/106360677.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-1-tp-ho-chi-minh/110220957.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110831026.htm...
# Crawled: 60.{'Giá nhà': ['6,19 tỷ'], 'Địa chỉ': ['Hiệp Thành 31, Phường Hiệp Thành, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['88 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110694272.htm'}
# Crawled: 61.{'Giá nhà': ['4,1 tỷ'], 'Địa chỉ': ['Nguyễn Sỹ Sách, Phường 15, Quận Tân Bình, Tp Hồ Chí Minh'], 'Diện tích': ['51 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/109631106.htm'}
# Crawled: 62.{'Giá nhà': ['6,36 tỷ'], 'Địa chỉ': ['1163/, Đường Lê Đức Thọ, Phường 13, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['54 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà phố liền kề'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830296.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-phu-nhuan-tp-ho-chi-minh/109180632.htm...
# Crawled: 63.{'Giá nhà': ['4,4 tỷ'], 'Địa chỉ': ['undefined, Hồ Học Lãm, Phường An Lạc, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['96.24 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110766298.htm#px=SR-stickyad-[PO-1][PL-top]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110603430.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110831014.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110720461.htm...
# Crawled: 64.{'Giá nhà': ['5,6 tỷ'], 'Địa chỉ': ['Hương Lộ 2, Phường Bình Trị Đông A, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['60 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110687525.htm#px=SR-stickyad-[PO-4][PL-top]'}
# Crawled: 65.{'Giá nhà': ['9,9 tỷ'], 'Địa chỉ': ['Tỉnh Lộ 10, Phường Tân Tạo, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['426 m²'], 'Số phòng ngủ': ['nhiều hơn 10 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110814433.htm#px=SR-stickyad-[PO-2][PL-top]'}
# Crawled: 66.{'Giá nhà': ['1,12 tỷ'], 'Địa chỉ': ['Bông Sao, Phường 5, Quận 8, Tp Hồ Chí Minh'], 'Diện tích': ['28 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-8-tp-ho-chi-minh/110816618.htm#px=SR-stickyad-[PO-5][PL-top]'}
# Crawled: 67.{'Giá nhà': ['5,15 tỷ'], 'Địa chỉ': ['Lê Văn Quới, Phường Bình Trị Đông, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['68 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': ['5'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110102493.htm#px=SR-stickyad-[PO-3][PL-top]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830973.htm#px=SR-special_display_ad-[PO-8][PL-default]...
# Crawled: 68.{'Giá nhà': ['4,85 tỷ'], 'Địa chỉ': ['Ụ Cây, Phường 10, Quận 8, Tp Hồ Chí Minh'], 'Diện tích': ['51.9 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['1'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-8-tp-ho-chi-minh/106360677.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-nha-be-tp-ho-chi-minh/110603374.htm#px=SR-special_display_ad-[PO-9][PL-default]...
# Crawled: 69.{'Giá nhà': ['5,03 tỷ'], 'Địa chỉ': ['Đường Trần Ðình Xu, Phường Cầu Kho, Quận 1, Tp Hồ Chí Minh'], 'Diện tích': ['51.1 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-1-tp-ho-chi-minh/110220957.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-4-tp-ho-chi-minh/110480689.htm...
# Crawled: 70.{'Giá nhà': ['2,999 tỷ'], 'Địa chỉ': ['Đường Nguyễn Văn Quá, Phường Đông Hưng Thuận, Quận 12, Tp Hồ Chí Minh'], 'Diện tích': ['46 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/110831026.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110383656.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830957.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830956.htm#px=SR-special_display_ad-[PO-13][PL-default]...
# Crawled: 71.{'Giá nhà': ['2,97 tỷ'], 'Địa chỉ': ['Đỗ Tấn Phong, Phường 9, Quận Phú Nhuận, Tp Hồ Chí Minh'], 'Diện tích': ['61 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-phu-nhuan-tp-ho-chi-minh/109180632.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830938.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110830940.htm...
# Crawled: 72.{'Giá nhà': ['6,2 tỷ'], 'Địa chỉ': ['Đường số 8, Phường Tân Kiểng, Quận 7, Tp Hồ Chí Minh'], 'Diện tích': ['30 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đang chờ sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110831014.htm'}
# Crawled: 73.{'Giá nhà': ['4,1 tỷ'], 'Địa chỉ': ['Đường số 16, Phường Hiệp Bình Chánh (Quận Thủ Đức cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['47 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110603430.htm'}
# Crawled: 74.{'Giá nhà': ['2,9 tỷ'], 'Địa chỉ': ['Đường Đỗ Nhuận, Phường Sơn Kỳ, Quận Tân Phú, Tp Hồ Chí Minh'], 'Diện tích': ['23 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110720461.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110830936.htm#px=SR-special_display_ad-[PO-16][PL-default]...
# Crawled: 75.{'Giá nhà': ['2,97 tỷ'], 'Địa chỉ': ['Đường Lê Văn Quới, Phường Bình Hưng Hoà A, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['35 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830973.htm#px=SR-special_display_ad-[PO-8][PL-default]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-4-tp-ho-chi-minh/110573947.htm...
# Crawled: 76.{'Giá nhà': ['7,2 tỷ'], 'Địa chỉ': ['Đường Huỳnh Tấn Phát, Thị trấn Nhà Bè, Huyện Nhà Bè, Tp Hồ Chí Minh'], 'Diện tích': ['80 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-nha-be-tp-ho-chi-minh/110603374.htm#px=SR-special_display_ad-[PO-9][PL-default]'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110395621.htm...
# Crawled: 77.{'Giá nhà': ['2,34 tỷ'], 'Địa chỉ': ['Nguyễn Khoái, Phường 2, Quận 4, Tp Hồ Chí Minh'], 'Diện tích': ['47.73 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-4-tp-ho-chi-minh/110480689.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/110802522.htm...
# Crawled: 78.{'Giá nhà': ['4,6 tỷ'], 'Địa chỉ': ['Hương Lộ 2, Phường Bình Trị Đông, Quận Bình Tân, Thành phố Hồ Chí Minh, 30000, Việt Nam, Phường Bình Trị Đông, Quận Bình Tân, Tp Hồ Chí Minh'], 'Diện tích': ['60 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110830957.htm'}
# Crawled: 79.{'Giá nhà': ['2,23 tỷ'], 'Địa chỉ': ['Hẻm 630 Thống Nhất, Phường 15, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['45.48 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110383656.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110463930.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/109776836.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110732258.htm...
# Crawled: 81.{'Giá nhà': ['5,8 tỷ'], 'Địa chỉ': ['Ni Sư Huỳnh Liên, Phường 10, Quận Tân Bình, Tp Hồ Chí Minh'], 'Diện tích': ['50 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['3'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830938.htm'}Crawled: 81.{'Giá nhà': ['10,9 tỷ'], 'Địa chỉ': ['Trường Chinh, Phường 14, Quận Tân Bình, Tp Hồ Chí Minh'], 'Diện tích': ['79 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830956.htm#px=SR-special_display_ad-[PO-13][PL-default]'}
#
# Crawled: 82.{'Giá nhà': ['9,3 tỷ'], 'Địa chỉ': ['Nguyễn Lâm, Phường 3, Quận Bình Thạnh, Tp Hồ Chí Minh'], 'Diện tích': ['57.3 m²'], 'Số phòng ngủ': ['5 phòng'], 'Tổng số tầng': ['5'], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110830940.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830286.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110589715.htm...
# Crawled: 83.{'Giá nhà': ['18,5 tỷ'], 'Địa chỉ': ['Lâm Văn Bền, Phường Tân Kiểng, Quận 7, Tp Hồ Chí Minh'], 'Diện tích': ['185 m²'], 'Số phòng ngủ': ['7 phòng'], 'Tổng số tầng': ['4'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-7-tp-ho-chi-minh/110830936.htm#px=SR-special_display_ad-[PO-16][PL-default]'}
# Crawled: 84.{'Giá nhà': ['570 triệu'], 'Địa chỉ': ['Phan Văn Hớn, Xã Bà Điểm, Huyện Hóc Môn, Tp Hồ Chí Minh'], 'Diện tích': ['64 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà mặt phố, mặt tiền'], 'Giấy tờ pháp lý': [None], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110395621.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/109079499.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-phu-tp-ho-chi-minh/110259874.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110830242.htm...
# Crawled: 85.{'Giá nhà': ['2,23 tỷ'], 'Địa chỉ': ['Tôn Đản, Phường 8, Quận 4, Tp Hồ Chí Minh'], 'Diện tích': ['49.5 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-4-tp-ho-chi-minh/110573947.htm'}
# Crawled: 86.{'Giá nhà': ['1,45 tỷ'], 'Địa chỉ': ['Đường Trần Thị Non, Xã Hưng Long, Huyện Bình Chánh, Tp Hồ Chí Minh'], 'Diện tích': ['80 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': ['2'], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-huyen-binh-chanh-tp-ho-chi-minh/110802522.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/110830202.htm...
# Crawled: 87.{'Giá nhà': ['1,99 tỷ'], 'Địa chỉ': ['Ụ Ghe, Phường Tam Phú (Quận Thủ Đức cũ), Thành phố Thủ Đức, Tp Hồ Chí Minh'], 'Diện tích': ['45 m²'], 'Số phòng ngủ': ['2 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-thanh-pho-thu-duc-tp-ho-chi-minh/110463930.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110830182.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-thanh-tp-ho-chi-minh/110830179.htm...
# Crawled: 88.{'Giá nhà': ['4,65 tỷ'], 'Địa chỉ': ['Đường Phạm Văn Bạch, Phường 15, Quận Tân Bình, Tp Hồ Chí Minh'], 'Diện tích': ['73 m²'], 'Số phòng ngủ': ['3 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-tan-binh-tp-ho-chi-minh/109776836.htm'}
# Crawled: 89.{'Giá nhà': ['4,55 tỷ'], 'Địa chỉ': ['Đường Phan Văn Trị, Phường 10, Quận Gò Vấp, Tp Hồ Chí Minh'], 'Diện tích': ['40 m²'], 'Số phòng ngủ': ['4 phòng'], 'Tổng số tầng': [None], 'Loại hình nhà ở': ['Nhà ngõ, hẻm'], 'Giấy tờ pháp lý': ['Đã có sổ'], 'url': 'https://www.nhatot.com/mua-ban-nha-dat-quan-go-vap-tp-ho-chi-minh/110732258.htm'}
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-binh-tan-tp-ho-chi-minh/110617169.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-quan-12-tp-ho-chi-minh/108086688.htm#px=SR-special_display_ad-[PO-12][PL-default]...
# ...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
# Try again https://www.nhatot.com/mua-ban-nha-dat-huyen-hoc-mon-tp-ho-chi-minh/110807215.htm...
